# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import tweepy

# %%
# Load tokens from creds file
# %run -i .secrets/creds.py

# %%
auth = tweepy.OAuthHandler(API_KEY, API_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

api = tweepy.API(auth)

school_tweets = api.search(q="school", lang="en", count = 100, tweet_mode = "extended")
print(len(school_tweets))
# Out:
# 100

# %%
for tweet in school_tweets[:10]:
    if "retweeted_status" in tweet._json.keys():
        print(tweet.retweeted_status.full_text)
    else:
        print(tweet.full_text)
    print("_____")
# Out:
# School doesn’t test your intelligence, it tests your memory. 🧠
# _____
# Parker can’t even make a proper first touch, can’t make a 1 meter pass yet he’s a captain who has been playing football since I was a bachelor in primary school
# _____
# Hey @RuPaul , check out what my niece @aew1028 did for school!  If she would ever get to meet you I'm tagging along.  @RuPaulsDragRace #DragRace https://t.co/Lj0FgG7Dzx
# _____
# NAHS is looking for a long term sub in the Math department for May &amp; June.  Great opportunity to gain experience in the teaching field.  Reach out with questions and apply using the link below:  https://t.co/TQMCEwgfI5
# @NorthAndoverHS @NA_GirlsSoccer @NA_Softball1
# _____
# The School of Justice Studies at Regional Campuses &amp; Sites Faculty would like to recognize Elizabethtown Site #CRJ student @Chadkwan1999 Chad Williams on nominating him for the Outstanding Senior Award for 20/21! Chad was awarded SJS Senior Certificate of Achievement for 20/21 https://t.co/D6r1vUXwwF
# _____
# SCHOOL NAPS USED TO GO CRAZY😂 SOMETHING ABOUT THAT HARD ASS DESK
# _____
# SCHOOL NAPS USED TO GO CRAZY😂 SOMETHING ABOUT THAT HARD ASS DESK
# _____
# A mother has been arrested after a child showed up to school with over 260 grams of cocaine in a backpack 🎒 https://t.co/oIBHt56nVF
# _____
# A youth was arrested just for having a pan, a motorcycle cap, a phone, a school bag, a sunglasses, a UN logo, and a poster in Burmese that says you can kill but we will not obey the terrorist government. How ridiculous!
# STOP INTERNET SHUTDOWN
# #Apr6Coup
# #WhatsHappeningInMyanmar https://t.co/tJ5p03G8tp
# _____
# @realreporter @adriandix @JM_Whiteside @TeriMooring @ianhanomansing @PennyDaflos Another surrey school has a whole class, the teacher, 3 EAs, librarian teacher and music teacher all self monitoring for two weeks.  Three kids in a class have covid. This isn’t slowing down.  I’m scared.
# _____

# %%
import requests
import os
import json

# Source: https://github.com/twitterdev/Twitter-API-v2-sample-code/blob/master/Filtered-Stream/filtered_stream.py

def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers


def get_rules(headers, bearer_token):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream/rules", headers=headers
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot get rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    return response.json()


def delete_all_rules(headers, bearer_token, rules):
    if rules is None or "data" not in rules:
        return None

    ids = list(map(lambda rule: rule["id"], rules["data"]))
    payload = {"delete": {"ids": ids}}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot delete rules (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    print(json.dumps(response.json()))


def set_rules(headers, delete, bearer_token):
    # You can adjust the rules if needed
    sample_rules = [
        {"value": "\"school\" lang:en sample:10", "tag": "school in English 10%"},
    ]
    payload = {"add": sample_rules}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        headers=headers,
        json=payload,
    )
    if response.status_code != 201:
        raise Exception(
            "Cannot add rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))


def get_stream(headers, set, bearer_token):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream", headers=headers, stream=True,
    )
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Cannot get stream (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            print(json.dumps(json_response, indent=4, sort_keys=True))

# %%
BEARER_TOKEN
# Out:
# 'AAAAAAAAAAAAAAAAAAAAAFjg8gAAAAAAMlGDk74WkgX2omlbvGKlSI7ujiU%3DUqa3GCto0H7y3WWQutTpJN8dLXYQAWXkoRqX9ZZZTOCOQMVl32'

# %%
bearer_token = BEARER_TOKEN
headers = create_headers(bearer_token)
rules = get_rules(headers, bearer_token)
delete = delete_all_rules(headers, bearer_token, rules)
set = set_rules(headers, delete, bearer_token)
get_stream(headers, set, bearer_token)
# Out:
# {"meta": {"sent": "2021-04-06T19:59:50.452Z"}}
# {"data": [{"value": "\"school\" lang:en sample:10", "tag": "school in English 10%", "id": "1379524268845899776"}], "meta": {"sent": "2021-04-06T19:59:52.022Z", "summary": {"created": 1, "not_created": 0, "valid": 1, "invalid": 0}}}
# 200
# {
#     "data": {
#         "id": "1379524235027218435",
#         "text": "@PandorasDisc back to school ughhhhhh"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524242568486912",
#         "text": "RT @magicalgirlnoir: It's the 6th day of Titty Monster Month 2021, and for today it's Suzune, or some say Rin, from Senran Kagura! Unfortun\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524245928075266",
#         "text": "@SheIsBeauty101 Old school hair spray \ud83d\ude06\ud83e\udd23\ud83d\ude06\ud83e\udd23 Big Hair Dint Care(obviously) https://t.co/UMVXzp5Url"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524249254252545",
#         "text": "everyday I find another Egyptian person on stan twt Im CONVINCED I'll end up actually being in the same school as them I just know it"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524260595662856",
#         "text": "RT @GretaThunberg: On Monday 12/4 9pm BST episode 1 of \u201cA Year To Change The World\u201d will air on @BBCOne .\nIt\u2019s a documentary series in 3 pa\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524269407928325",
#         "text": "RT @itslittletunny: Kids who threw trash all over the ground at school to \"give the janitors something to do\" grew up to be crypto-bros who\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524273161695232",
#         "text": "literally why is school so fun bye"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524276135604231",
#         "text": "RT @melaninxqueen: just found a rare photo of my granddad learning in an all-white segregated school \ud83d\ude0c he was so inspiring \ud83d\ude0d\ud83d\ude2d\ud83d\ude4c\ud83c\udffe https://t.c\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524281168723975",
#         "text": "@Louisianaboater @AndyBCampbell I imagine every school within driving distance take their science classes for field trips to you to learn love of nature and protecting the environment."
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524288701665286",
#         "text": "@zaptiee Started my caffeine addiction in grad school. \nLiterally had a doc tell me to chill out (up to three NOS and a pot of coffee a day) or id have arrhythmia. Start slow cause the headaches are awful"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524295001567242",
#         "text": "RT @littlecocobeann: @najaee___ @curlybeviie bc it was \u201ctaking money away from the school\u201d they wanted us to use the vending machines &amp; shi\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524294988996614",
#         "text": "@a_twoset MY MOM ALREADY DID THAT IM ON SCHOOL IPAD"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524299585945600",
#         "text": "@FINE13WALLS I AM IN SCHOOL MA'AM"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524304224854016",
#         "text": "RT @clarenicholasuk: Handmade with love. Vintage Look.\nMade from an old school bench and scaffold board.\n\nhttps://t.co/9uX3DOsImH"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524307165011973",
#         "text": "RT @GovernorTomWolf: I\u2019ll veto this discriminatory ban if it reaches my desk.\n\nTo Pennsylvania\u2019s trans youth: You belong. You are valued. P\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524308813238272",
#         "text": "Vaccinated girl summer: girl gang edition. \ud83d\udc59https://t.co/cfcUTgAFMR"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524308838576132",
#         "text": "RT @drswapnapatker: My school,college friends received requests on Facebook from #sanjayRaut Some family,friends called to #Shivsena Bhavan\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524309656420355",
#         "text": "RT @ArizonaWestern: Our Student Government Association is looking for dedicated students to represent the student body in the 2021\u20132022 sch\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524309652152321",
#         "text": "\"This outdated system of residential assignment hurts minorities, in particular, and completely disregards the fact that each child is different.\"\n\nCheck out a recent article from @CooperConway1.\n\nhttps://t.co/HSoLBUL3nP"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524311329955855",
#         "text": "Ga.\u2019s largest school district releases timeline to fill school superintendent position https://t.co/neCjjMaV0q"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524311355129863",
#         "text": "Once the elementary school rezoning plan is approved by the Board of Education, it will go into effect at the beginning of next school year. https://t.co/TQ0VdwcCoX"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524311367610371",
#         "text": "Alexandria Scholars is a scholarship program that grants $5,000 annually to three SFUSD high school students who will be attending a two- or four-year college or university of their choice to major in one of the STEM fields. \ud83e\uddea Apply by April 12th! https://t.co/VnkRBcPdvj https://t.co/HcXV2BSUAv"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524312193855489",
#         "text": "RT @KariHamerschlag: My @CalMatters op-ed w/ @chrsdcook:\n\"Let\u2019s transform school food so that it nourishes kids\u2019 health &amp; creates new oppor\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524319731154944",
#         "text": "I\u2019m so behind in school it\u2019s so disgusting \ud83d\ude16"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524326861504514",
#         "text": "RT @TelBabe: Doesn't seem long ago we were singing Jerusalem in school assemblies; flying the Union Jack in Carnaby Street; cheering Michae\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524326886678533",
#         "text": "S/O to the kid I had summer school with who ordered 10 pizzas for lunch and sold slices. Had to give the school all the money he made because he cut into their lunch sales. https://t.co/2au1q8lCxm"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524331915599873",
#         "text": "RT @beth_torstenson: I just voted! #Wisconsin, please go out and vote for your local officials and for Deborah Kerr who is running for stat\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524333173927941",
#         "text": "RT @Mosa13Mosa: A teacher in #Idlib at a school called, \u201cModel School of Buds\u201d, gives a model in brutality and cruelty. What a contradictio\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524333995970565",
#         "text": "RT @Prowriters001A: Hi, PAY us to handle any of the following or ANY OTHER SCHOOL work.\n\u2022Assignments\n\u2022 Essays \n\u2022Due homework \n\u2022Online class\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524335250124811",
#         "text": "@JackMorris1867 @Patriotgirl0000 @becs1007 Yeah, now they come to us for advice lol\n\nBeen telling friends that have challenges with daily child care for a couple weeks now to start sorting it out... because school closures are imminent and would happen between Easter and the revised school break.... and here we are \ud83e\udd14"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1379524348239876096",
#         "text": "RT @UN_Women: Respect women at work.\nRespect women at home.\nRespect women at school.\nRespect women in politics.\nRespect women in science.\nR\u2026"
#     },
#     "matching_rules": [
#         {
#             "id": 1379524268845899776,
#             "tag": "school in English 10%"
#         }
#     ]
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Documents/GitHub/twitter_sentiment/.secrets/creds.py in <module>
#       4 delete = delete_all_rules(headers, bearer_token, rules)
#       5 set = set_rules(headers, delete, bearer_token)
# ----> 6 get_stream(headers, set, bearer_token)
#
# ~/Documents/GitHub/twitter_sentiment/.secrets/creds.py in get_stream(headers, set, bearer_token)
#      71             )
#      72         )
# ---> 73     for response_line in response.iter_lines():
#      74         if response_line:
#      75             json_response = json.loads(response_line)
#
# ~/opt/anaconda3/envs/twitter_proj/lib/python3.8/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     795         pending = None
#     796
# --> 797         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     798
#     799             if pending is not None:
#
# ~/opt/anaconda3/envs/twitter_proj/lib/python3.8/site-packages/requests/models.py in generate()
#     751             if hasattr(self.raw, 'stream'):
#     752                 try:
# --> 753                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     754                         yield chunk
#     755                 except ProtocolError as e:
#
# ~/opt/anaconda3/envs/twitter_proj/lib/python3.8/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# ~/opt/anaconda3/envs/twitter_proj/lib/python3.8/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     762
#     763             while True:
# --> 764                 self._update_chunk_length()
#     765                 if self.chunk_left == 0:
#     766                     break
#
# ~/opt/anaconda3/envs/twitter_proj/lib/python3.8/site-packages/urllib3/response.py in _update_chunk_length(self)
#     692         if self.chunk_left is not None:
#     693             return
# --> 694         line = self._fp.fp.readline()
#     695         line = line.split(b";", 1)[0]
#     696         try:
#
# ~/opt/anaconda3/envs/twitter_proj/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/envs/twitter_proj/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/envs/twitter_proj/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
